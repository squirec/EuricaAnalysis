// %%
TFile *ipf = new TFile("46_124gg200s.root");

// %%
ipf->ls();
// Out:
// TFile**		46_124gg200s.root
//  TFile*		46_124gg200s.root
//   KEY: TH2F	gg;1	caxe:caye {abs(caxt-cayt)<50.000000 && decaytime>0.000000&&decaytime<200.000000}
//   KEY: TH1F	ae;1	ae {1 && decaytime>0.000000 && decaytime<200.000000}
//   KEY: TH1D	Tpj;1	caxe:caye {abs(caxt-cayt)<50.000000 && decaytime>0.000000&&decaytime<200.000000}
//   KEY: TH1D	TpjBg;1	TpjBg
//   KEY: TH1D	TpjPeak;1	TpjBg
//   KEY: TH2I	ggbmat;1	bgmat for gg
//   KEY: TH2I	ggmat;1	gg with backsub

// %%
TCanvas *c1 = new TCanvas;
Tpj->Draw();
c1->Draw();

// %%
TpjPeak->Draw();
c1->Draw();

// %%
TpjBg->Draw();
c1->Draw();

// %%
gg->Draw("colz");
c1->SetLogz();
c1->Draw();

// %%
ggbmat->Draw("colz");
c1->Draw();

// %%
ggmat->Draw("colz");
c1->Draw();
